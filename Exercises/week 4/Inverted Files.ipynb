# %% [markdown]
# ## 📚 Exercise 2: Inverted Files
#
# In this exercise, we will understand the functioning of the Inverted Files and how implement them using MapReduce.
#
# ### Overview
#
# We learnt in the lecture that terms are typically stored in an inverted list. Now, in the inverted list, instead of only storing document identifiers of the documents in which the term appears, assume we also store an *offset* of the appearance of a term in a document. An $offset$ of a term $l_k$ given a document is defined as the number of words between the start of the document and $l_k$. Thus our inverted list is now:
#
# $l_k= \langle f_k: \{d_{i_1} \rightarrow [o_1,\ldots,o_{n_{i_1}}]\},
# \{d_{i_2} \rightarrow [o_1,\ldots,o_{n_{i_2}}]\}, \ldots,
# \{d_{i_k} \rightarrow [o_1,\ldots,o_{n_{i_k}}]\} \rangle$
#
# This means that in document $d_{i_1}$ term $l_k$ appears $n_{i_1}$ times and at offset $[o_1,\ldots,o_{n_{i_1}}]$, where $[o_1,\ldots,o_{n_{i_1}}]$ are sorted in ascending order, these type of indices are also known as term-offset indices. An example of a term-offset index is as follows:
#
# **Obama** = $⟨4 : {1 → [3]},{2 → [6]},{3 → [2,17]},{4 → [1]}⟩$
#
# **Governor** = $⟨2 : {4 → [3]}, {7 → [14]}⟩$
#
# **Election** = $⟨4 : {1 → [1]},{2 → [1,21]},{3 → [3]},{5 → [16,22,51]}⟩$
#
# Which is to say that the term **Governor** appear in 2 documents. In document 4 at offset 3, in document 7 at offset 14. Now let us consider the *SLOP/x* operator in text retrieval. This operator has the syntax: *QueryTerm1 SLOP/x QueryTerm2* finds occurrences of *QueryTerm1* within $x$ (but not necessarily in that order) words of *QueryTerm2*, where $x$ is a positive integer argument ($x \geq 1$). Thus $x = 1$ demands that *QueryTerm1* be adjacent to *QueryTerm2*.
#
# ### Questions
#
# 1. List the set of documents that satisfy the query **Obama** *SLOP/2* **Election**.
# 2. List each set of values for which the query **Obama** *SLOP/x* **Election** has a different set of documents as answers (starting from $x = 1$).
# 3. Consider the general procedure for "merging" two term-offset inverted lists for a given document, to determine where the document satisfies a *SLOP/x* clause (since in general there will be many offsets at which each term occurs in a document). Let $L$ denote the total number of occurrences of the two terms in the document. Assume we have a pointer to the list of occurrences of each term and can move the pointer along this list. As we do so we check whether we have a hit for $SLOP/x$ (i.e. the $SLOP/x$ clause is satisfied). Each move of either pointer counts as a step. Based on this assumption is there a general "merging" procedure to determine whether the document satisfies a $SLOP/x$ clause, for which the following is true? Justify your answer.
#
#     1. The merge can be accomplished in a number of steps linear in $L$ regardless of $x$, and we can ensure that each pointer moves only to the right (i.e. forward).
#     2. The merge can be accomplished in a number of steps linear in $L$, but a pointer may be forced to move to the left (i.e. backwards).
#     3. The merge can require $x \times L$ steps in some cases.

# %% [markdown]
# **Answer**
#
# 1. Document 1 and Document 3
# 2. x=1, x=2, x=5
# 3. A

# %% [markdown]
# ## Create inverted files using MapReduce
# In this exercise, we want to create the inverted files using the MapReduce framework. Write the **map** and **reduce** function.
# Note that the code of **run_mapreduce** is just a simulation of the behavior of  map-reduce system.
#
# ## Goal:
# - Create inverted files using the MapReduce framework.
# - Test the implementation on `epfldocs.txt` data.
#
# ### What you are learning in this exercise:
# - Having a better understanding of inverted files.
# - Learn how to implement inverted files using the MapReduce framework.

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import string
from nltk.corpus import stopwords
import math
from collections import Counter
import numpy as np
nltk.download('stopwords')
nltk.download('punkt')

stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sunyukang/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/sunyukang/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Tokenize, stem a document
def tokenize(text):
    """
    It tokenizes and stems an input text.
    
    :param text: str, with the input text
    :return: list, of the tokenized and stemmed tokens.
    """
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    return " ".join([stemmer.stem(word.lower()) for word in tokens])

with open("epfldocs.txt") as f:
    content = f.readlines()
original_documents = [x.strip() for x in content] 
documents = [tokenize(d).split() for d in original_documents]
docs_n_doc_ids = list(zip(range(len(documents)), documents))

# %%
# Take a pair (doc_id, content). Example: (0, ['how', 'to', 'bake', 'bread', 'without', 'bake', 'recip'])
# Return: list of (word, doc_id). Example: ('bake', 0)
# For simplicity, we assume each mapper handles a document
def map_function(doc_id, content):
    keyvals = []
    for word in content:
        # YOUR CODE HERE
        
        keyvals.append([word, doc_id])
    return keyvals

# %%
# Take a list of pairs (word, doc_id). Example:  [('bake', 0), ('bake', 0), ('bake', 3)]
# Return: (word, frequency, list of document ids). Example ('bake', 3, [0, 0, 3])
# For simplicity, we assume each reducer handles a word
def reduce_function(lst):
    total = 0
    word = lst[0][0]
    doc_ids = []
    for w, doc_id in lst:
        assert(word==w) # Assume each reducer handles 1 word
        # YOUR CODE HERE
        total = total + 1
        doc_ids.append(doc_id)
    return (word, total, doc_ids)

# %%
# We simulate the mapreduce framework by this function
def run_mapreduce(docs_n_doc_ids):
    # Map phase
    key_values = []
    for doc_id, doc_content in docs_n_doc_ids:
        key_values.extend(map_function(doc_id, doc_content))
    # Shuffle phase
    values = set(map(lambda x:x[0], key_values))
    print(key_values)
    grouped_key_values = [[y for y in key_values if y[0]==x] for x in values]
    # Reduce phase
    inverted_files = []
    for grouped_key_value in grouped_key_values:
        word, total, doc_ids = reduce_function(grouped_key_value)
        inverted_files.append((word, total, doc_ids))
    return inverted_files

# %%
run_mapreduce(docs_n_doc_ids)
# Out:
# [['congrat', 0], ['to', 0], ['ethen', 0], ['5th', 0], ['place', 0], ['and', 0], ['epflen', 0], ['10th', 0], ['place', 0], ['httpstco8rlp0zzhyb', 0], ['if', 1], ['that', 1], ['not', 1], ['a', 1], ['stand', 1], ['ovat', 1], ['at', 1], ['epflen', 1], ['🏆🙃😜👾🚀🎉', 1], ['httpstco23kjig8pxt', 1], ['time', 2], ['for', 2], ['open', 2], ['farm', 2], ['pitch', 2], ['openfood', 2], ['opendata', 2], ['epfl', 2], ['httpstco7lkkao5780', 2], ['good', 3], ['opportun', 3], ['for', 3], ['ethen', 3], ['epflen', 3], ['epflpark', 3], ['uzhnewsen', 3], ['httpstcov3tojtyjqd', 3], ['excit', 4], ['news', 4], ['world', 4], ['univers', 4], ['rank', 4], ['20162017', 4], ['by', 4], ['subject', 4], ['comput', 4], ['scienc', 4], ['no1', 4], ['eth', 4], ['amp', 4], ['epfl', 4], ['on', 4], ['no8', 4], ['congrat', 4], ['httpstcoarslxzoshq', 4], ['epfl', 5], ['cryptotoken', 5], ['free', 5], ['energi', 5], ['httpstcovh9qgloqrr', 5], ['httpstco6utnj68psc', 5], ['httpstcogtxlhi6lt', 5], ['httpstcozyenraseir', 5], ['get', 5], ['rich', 5], ['scientist', 6], ['discov', 6], ['hidden', 6], ['pattern', 6], ['of', 6], ['brain', 6], ['activ', 6], ['httpstcohblrytdmtt', 6], ['epfl', 6], ['edacyhq', 7], ['with', 7], ['edaci', 7], ['invest', 7], ['in', 7], ['yourself', 7], ['httpstcox2y212dkup', 7], ['deadlin', 8], ['19052017', 8], ['against', 8], ['breast', 8], ['cancer', 8], ['i', 8], ['research', 8], ['fund', 8], ['httpstcol4mhqa7upb', 8], ['epfl', 8], ['againstbc', 8], ['robot', 9], ['transform', 9], ['into', 9], ['furnitur', 9], ['at', 9], ['epfl', 9], ['novemb', 9], ['kamiahok', 9], ['httpstcojjpc1puyum', 9], ['microsoft', 10], ['presid', 10], ['bradsmi', 10], ['and', 10], ['epfl', 10], ['ebugnion', 10], ['at', 10], ['wef18', 10], ['on', 10], ['digitalgenevaconvent', 10], ['and', 10], ['digitaltrust', 10], ['import', 10], ['topic', 10], ['ethrat', 10], ['epflen', 10], ['httpstcoxg2cmw3szm', 10], ['ateli', 11], ['de', 11], ['travail', 11], ['sur', 11], ['la', 11], ['futur', 11], ['traversé', 11], ['de', 11], ['la', 11], ['rade', 11], ['à', 11], ['genev', 11], ['avec', 11], ['cantongenev', 11], ['epfl', 11], ['hslu', 11], ['etc', 11], ['et', 11], ['la', 11], ['hesso', 11], ['hei', 11], ['hepia', 11], ['heiafr', 11], ['httpstco2vqqgqhact', 11], ['formid', 12], ['je', 12], ['sui', 12], ['fan', 12], ['du', 12], ['projet', 12], ['de', 12], ['la', 12], ['time', 12], ['machin', 12], ['il', 12], ['sera', 12], ['donc', 12], ['possibl', 12], ['de', 12], ['revoir', 12], ['la', 12], ['conférenc', 12], ['sur', 12], ['votr', 12], ['chaîn', 12], ['youtub', 12], ['si', 12], ['jai', 12], ['bien', 12], ['lu', 12], ['le', 12], ['précédent', 12], ['commentair', 12], ['merci', 12], ['de', 12], ['signal', 12], ['quand', 12], ['cett', 12], ['dernièr', 12], ['sera', 12], ['en', 12], ['lign', 12], ['archiv', 12], ['numeriqu', 12], ['httpstcortxwav5pan', 12], ['the', 13], ['27', 13], ['member', 13], ['of', 13], ['the', 13], ['wef', 13], ['global', 13], ['univers', 13], ['leader', 13], ['forum', 13], ['includ', 13], ['switzerland', 13], ['ethen', 13], ['and', 13], ['epflen', 13], ['are', 13], ['respons', 13], ['for', 13], ['a', 13], ['larg', 13], ['proport', 13], ['of', 13], ['the', 13], ['world', 13], ['’', 13], ['s', 13], ['scientif', 13], ['public', 13], ['a', 13], ['new', 13], ['studi', 13], ['reveal', 13], ['httpstcon2fe3bxfzh', 13], ['httpstcokpg9gtylsq', 13], ['switzerland', 14], ['is', 14], ['work', 14], ['hard', 14], ['to', 14], ['keep', 14], ['up', 14], ['with', 14], ['the', 14], ['best', 14], ['brjsa', 14], ['robot', 14], ['srindustryday', 14], ['httpstcojosupjdg7k', 14], ['free', 15], ['yoga', 15], ['event', 15], ['host', 15], ['by', 15], ['indian', 15], ['student', 15], ['of', 15], ['epfl', 15], ['lausann', 15], ['ambassador', 15], ['gill', 15], ['of', 15], ['cdmissionindia', 15], ['will', 15], ['attend', 15], ['unil', 15], ['myswitzerlandf', 15], ['epflen', 15], ['httpstcoxnciwuqcxw', 15], ['aviat', 16], ['la', 16], ['suiss', 16], ['a', 16], ['désormai', 16], ['son', 16], ['centr', 16 ...
# [('sall', 1, [894]),
#  ('financ', 2, [569, 821]),
#  ('danné', 1, [93]),
#  ('popul', 6, [104, 122, 292, 459, 498, 789]),
#  ('baychimokin', 1, [240]),
#  ('rape', 2, [122, 979]),
#  ('advanc', 3, [84, 226, 903]),
#  ('micro', 2, [66, 544]),
#  ('eksobion', 1, [871]),
#  ('exclusif', 1, [683]),
#  ('expans', 1, [171]),
#  ('imperialcolleg', 2, [76, 933]),
#  ('inscript', 2, [277, 958]),
#  ('construir', 1, [958]),
#  ('gorgeou', 1, [1002]),
#  ('httpstcoyyfhsr2qsb', 1, [121]),
#  ('diplomtypu', 1, [188]),
#  ('inject', 1, [303]),
#  ('tackl', 1, [879]),
#  ('httpstcoclpyvpputz', 1, [854]),
#  ('liaison', 1, [821]),
#  ('994', 2, [191, 257]),
#  ('séduisent', 1, [388]),
#  ('robotera', 1, [828]),
#  ('fiveminut', 1, [564]),
#  ('fintech', 3, [19, 127, 538]),
#  ('deconvolutionlab2', 2, [80, 100]),
#  ('campus…', 1, [326]),
#  ('lu', 1, [12]),
#  ('edacyhq', 4, [7, 56, 233, 269]),
#  ('erf2018', 1, [102]),
#  ('ist', 3, [105, 167, 319]),
#  ('httpstcojkukx2ke3r', 1, [144]),
#  ('optimis', 1, [636]),
#  ('httpstco6yiyk7cyi1', 1, [1016]),
#  ('alexi', 1, [523]),
#  ('jeandaniel', 1, [552]),
#  ('httpstcofhrlh3haa9', 1, [408]),
#  ('reliabl', 3, [329, 485, 797]),
#  ('ateli', 3, [11, 265, 265]),
#  ('a3forum', 2, [104, 292]),
#  ('savoi', 1, [185]),
#  ('—', 1, [260]),
#  ('wyplosz', 1, [921]),
#  ('campaign', 1, [981]),
#  ('portabl', 3, [173, 690, 854]),
#  ('✨', 1, [141]),
#  ('httpstcoxorkl6jcgv', 1, [1071]),
#  ('mauric', 2, [360, 360]),
#  ('sphere', 1, [221]),
#  ('lacustr', 2, [167, 252]),
#  ('httpstco2byw3asuc2', 1, [267]),
#  ('lac', 1, [766]),
#  ('improbresearch', 2, [230, 380]),
#  ('commenc', 3, [331, 452, 1063]),
#  ('innova…', 1, [836]),
#  ('nest', 1, [659]),
#  ('tortur', 5, [122, 122, 163, 240, 979]),
#  ('peopl',
#   15,
#   [107,
#    122,
#    278,
#    323,
#    337,
#    507,
#    507,
#    511,
#    526,
#    649,
#    722,
#    813,
#    878,
#    904,
#    1029]),
#  ('tonight', 4, [427, 553, 652, 974]),
#  ('swissskil', 1, [346]),
#  ('httpstcovmkww0q2gq', 1, [201]),
#  ('joël', 1, [785]),
#  ('carmelatroncoso', 1, [68]),
#  ('cooper', 1, [71]),
#  ('johnni', 1, [1012]),
#  ('plate', 1, [485]),
#  ('unser', 1, [638]),
#  ('académi', 1, [710]),
#  ('dakar', 1, [233]),
#  ('httpstcookq8sxesiv', 1, [642]),
#  ('dévoil', 1, [651]),
#  ('httpstcojrwbq3pngc', 1, [869]),
#  ('fiberopt', 1, [544]),
#  ('httpstcot2okbgyqsz', 1, [749]),
#  ('love', 6, [125, 263, 418, 466, 624, 743]),
#  ('httpstcoxjkykw636q', 1, [982]),
#  ('aisten', 1, [870]),
#  ('at',
#   154,
#   [1,
#    9,
#    10,
#    30,
#    30,
#    31,
#    31,
#    32,
#    33,
#    39,
#    60,
#    64,
#    68,
#    83,
#    84,
#    87,
#    95,
#    107,
#    137,
#    141,
#    176,
#    180,
#    189,
#    195,
#    210,
#    212,
#    213,
#    213,
#    215,
#    222,
#    225,
#    227,
#    235,
#    238,
#    257,
#    269,
#    270,
#    276,
#    292,
#    301,
#    301,
#    306,
#    308,
#    312,
#    313,
#    316,
#    323,
#    336,
#    339,
#    350,
#    376,
#    387,
#    387,
#    390,
#    411,
#    419,
#    431,
#    458,
#    459,
#    464,
#    465,
#    466,
#    470,
#    479,
#    484,
#    485,
#    503,
#    504,
#    504,
#    505,
#    507,
#    512,
#    513,
#    532,
#    545,
#    547,
#    553,
#    555,
#    557,
#    560,
#    561,
#    572,
#    575,
#    577,
#    577,
#    588,
#    591,
#    594,
#    595,
#    596,
#    609,
#    611,
#    612,
#    622,
#    624,
#    626,
#    628,
#    629,
#    635,
#    640,
#    641,
#    663,
#    689,
#    703,
#    731,
#    733,
#    741,
#    741,
#    743,
#    748,
#    755,
#    760,
#    760,
#    762,
#    764,
#    772,
#    774,
#    777,
#    785,
#    803,
#    804,
#    804,
#    807,
#    808,
#    810,
#    836,
#    838,
#    865,
#    872,
#    873,
#    873,
#    897,
#    898,
#    903,
#    906,
#    917,
#    928,
#    934,
#    941,
#    944,
#    950,
#    973,
#    974,
#    986,
#    987,
#    990,
#    990,
#    992,
#    1009,
#    1014,
#    1032,
#    1036,
#    1055,
#    1064]),
#  ('zürich', 2, [443, 844]),
#  ('hts18', 1, [898]),
#  ('détermin', 1, [1031]),
#  ('httpstco8owqib0csc', 1, [96]),
#  ('encourag', 3, [233, 910, 987]),
#  ('der',
#   13,
#   [167, 167, 188, 241, 309, 619, 619, 737, 822, 890, 969, 1015, 1015]),
#  ('shout', 1, [323]),
#  ('myswitzerlandf', 1, [15]),
#  ('phbismuth', 1, [472]),
#  ('texa', 2, [215, 969]),
#  ('theoret', 1, [685]),
#  ('jo', 2, [915, 1042]),
#  ('sunrised', 1, [582]),
#  ('enclench', 1, [627]),
#  ('masschallengech', 3, [143, 247, 587]),
#  ('jilasci', 1, [431]),
#  ('help', 12, [60, 109, 236, 359, 450, 511, 530, 547, 818, 948, 979, 1029]),
#  ('connect', 1, [62]),
#  ('stupéfiant', 1, [627]),
#  ('bei', 1, [619]),
#  ('neulich', 1, [1011]),
#  ('combien', 1, [687]),
#  ('microbiolog', 1, [378]),
#  ('httpstcoyu4r1mhcjo', 1, [784]),
#  ('mobil', 8, [37, 104, 250, 275, 292, 294, 468, 842]),
#  ('preserv', 1, [299]),
#  ('girl', 4, [525, 525, 528, 707]),
#  ('combin', 3, [126, 211, 795]),
#  ('📽️', 1, [463]),
#  ('myswitzerland', 1, [749]),
#  ('httpstcooheor1ejhp', 1, [826]),
#  ('soin', 1, [386]),
#  ('staircas', 1, [455]),
#  ('httpstcozyenraseir', 1, [5]),
#  ('httpstcohpfqgy1yuf', 1, [304]),
#  ('5', 7, [333, 350, 393, 489, 560, 586, 1014]),
#  ('httpstco1vtjkucjfa', 1, [444]),
#  ('analys', 2, [365, 740]),
#  ('enough', 1, [965]),
#  ('numériqu', 8, [202, 243, 382, 565, 723, 958, 958, 1024]),
#  ('shed', 1, [597]),
#  ('janetgh', 1, [785]),
#  ('claud', 3, [138, 570, 829]),
#  ('idea', 1, [626]),
#  ('doehlergroup', 1, [522]),
#  ('hep', 1, [20]),
#  ('remain', 1, [66]),
#  ('driverless', 1, [1044]),
#  ('giraulthubert', 2, [275, 1013]),
#  ('after', 12, [90, 104, 175, 272, 481, 525, 591, 611, 912, 948, 972, 1029]),
#  ('httpstcosoiiictqnr', 1, [70]),
#  ('httpstcocjnak2wc0p', 1, [225]),
#  ('faculti', 1, [88]),
#  ('eindhoven', 2, [419, 898]),
#  ('httpstcohvhfodh1ai', 1, [1000]),
#  ('1980', 1, [1069]),
#  ('wysssupport', 1, [114]),
#  ('pour',
#   63,
#   [43,
#    63,
#    70,
#    118,
#    123,
#    168,
#    182,
#    197,
#    244,
#    277,
#    325,
#    325,
#    345,
#    345,
#    366,
#    369,
#    382,
#    383,
#    392,
#    402,
#    429,
#    462,
#    472,
#    488,
#    548,
#    565,
#    567,
#    602,
#    602,
#    610,
#    653,
#    706,
#    723,
#    742,
#    752,
#    801,
#    824,
#    827,
#    842,
#    848,
#    874,
#    874,
#    876,
#    895,
#    896,
#    919,
#    920,
#    939,
#    978,
#    988,
#    989,
#    996,
#    1001,
#    1010,
#    1019,
#    1024,
#    1025,
#    1030,
#    1037,
#    1042,
#    1043,
#    1050,
#    1066]),
#  ('shameless', 1, [290]),
#  ('httpstco1fgggsnrkl', 1, [95]),
#  ('battin', 1, [119]),
#  ('httpstcopybcdhk9rp', 1, [151]),
#  ('httpstcovsh31g6vpl', 1, [56]),
#  ('httpstcojh2nndxm00', 1, [789]),
#  ('drpetti', 2, [320, 381]),
#  ('seethrough', 1, [396]),
#  ('humain', 4, [183, 610, 978, 1038]),
#  ('httpstcotcovytrn9i', 1, [983]),
#  ('httpstcopbmkt2wxcg', 1, [595]),
#  ('limpress', 1, [287]),
#  ('httpstcopb8uasa3sa', 1, [1050]),
#  ('httpstcoo5ido16day', 1, [492]),
#  ('247', 1, [21]),
#  ('wild', 1, [557]),
#  ('handi', 1, [845]),
#  ('exchang', 1, [106]),
#  ('demo', 3, [316, 323, 518]),
#  ('httpstcog0hzwjpurg', 1, [465]),
#  ('mond', 5, [356, 568, 913, 923, 1037]),
#  ('30th', 1, [762]),
#  ('epflsb', 2, [406, 757]),
#  ('httpstcojlnocxclmg', 1, [868]),
#  ('matrixbind', 1, [349]),
#  ('vincent', 1, [463]),
#  ('httpstcompy2qdid9o', 1, [631]),
#  ('cranfielduni', 1, [471]),
#  ('paragraph', 1, [548]),
#  ('musi', 2, [688, 801]),
#  ('gregoir', 1, [114]),
#  ('httpstco9qvu4leli0', 1, [728]),
#  ('veri', 11, [125, 260, 293, 307, 333, 575, 629, 771, 808, 830, 963]),
#  ('httpstcop96wkiy9zc', 1, [790]),
#  ('verg', 3, [234, 241, 387]),
#  ('leprosi', 2, [284, 777]),
#  ('testament', 1, [70]),
#  ('httpstco8f4bnl7aa', 1, [458]),
#  ('worldwid', 1, [631]),
#  ('becom', 6, [143, 236, 259, 628, 885, 910]),
#  ('rest', 1, [325]),
#  ('soutenir', 1, [1016]),
#  ('logo', 1, [455]),
#  ('possibl', 8, [12, 24, 44, 67, 153, 467, 797, 932]),
#  ('gene', 3, [35, 498, 943]),
#  ('ahead', 2, [474, 992]),
#  ('lhonneur', 1, [844]),
#  ('gan', 2, [859, 859]),
#  ('httpstcoh45eoihqmh', 1, [819]),
#  ('httpstconiyyitetug', 1, [852]),
#  ('exzellenz', 1, [954]),
#  ('cern', 4, [210, 541, 594, 874]),
#  ('rencontr', 3, [265, 463, 653]),
#  ('meant', 1, [938]),
#  ('magnet', 1, [558]),
#  ('attent', 2, [773, 1049]),
#  ('neighborhood', 1, [513]),
#  ('avc', 1, [43]),
#  ('httpstco4yts0a28x', 1, [403]),
#  ('latest', 9, [218, 232, 460, 496, 552, 745, 747, 864, 952]),
#  ('immunotherapi', 2, [349, 529]),
#  ('bibliothequ', 4, [168, 325, 345, 860]),
#  ('review', 4, [225, 334, 694, 948]),
#  ('chi', 1, [658]),
#  ('mail', 1, [641]),
#  ('astro4dev', 1, [869]),
#  ('travel', 4, [136, 179, 372, 930]),
#  ('httpstco27enjydfx9', 1, [978]),
#  ('👌☀️', 1, [992]),
#  ('appel', 1, [363]),
#  ('seasonaldepress', 1, [714]),
#  ('trevp', 1, [68]),
#  ('httpstco2hvx5go6s6', 1, [472]),
#  ('stabl', 3, [268, 485, 628]),
#  ('elfirepfl', 1, [30]),
#  ('appreci', 1, [151]),
#  ('lebenswissenschaftenundtechnologi', 1, [309]),
#  ('profitez', 1, [929]),
#  ('gibt', 1, [828]),
#  ('traveltuesday', 1, [136]),
#  ('être', 1, [283]),
#  ('split', 1, [918]),
#  ('httpstcouwvuz7i9v9', 1, [501]),
#  ('nccrmarvel', 1, [545]),
#  ('mobilis', 1, [541]),
#  ('myself', 1, [612]),
#  ('nviso', 1, [448]),
#  ('braintovehicl', 1, [387]),
#  ('deux', 3, [403, 548, 706]),
#  ('twitter', 2, [426, 776]),
#  ('exot', 1, [110]),
#  ('fabric', 2, [327, 1000]),
#  ('luciano', 1, [22]),
#  ('allègrement', 1, [927]),
#  ('httpstco4qqqksoafm', 1, [942]),
#  ('recogn', 1, [547]),
#  ('jfellay', 1, [922]),
#  ('colab', 1, [176]),
#  ('httpstcolqtqqyt5mx', 1, [224]),
#  ('toxic', 1, [641]),
#  ('ugli', 2, [575, 1002]),
#  ('mbryzek', 1, [427]),
#  ('sfgeneva', 1, [672]),
#  ('httpstcoqogirkkqs', 1, [1066]),
#  ('as',
#   19,
#   [35,
#    44,
#    44,
#    58,
#    88,
#    104,
#    229,
#    270,
#    328,
#    373,
#    373,
#    390,
#    490,
#    527,
#    589,
#    757,
#    875,
#    908,
#    912]),
#  ('httpstcoe2dcsoafrj', 1, [236]),
#  ('httpstcox4bebdkova', 1, [1059]),
#  ('canard', 1, [1052]),
#  ('httpstcoyyoucaecgq', 1, [503]),
#  ('elliottrham', 1, [979]),
#  ('httpstcox2y212dkup', 1, [7]),
#  ('encrypt', 1, [930]),
#  ('beltandroaddesk', 1, [530]),
#  ('perl', 1, [886]),
#  ('1215h', 1, [513]),
#  ('aiidateam', 1, [545]),
#  ('cest', 6, [174, 265, 342, 837, 877, 920]),
#  ('securityprivaci', 1, [640]),
#  ('sa\u200b', 1, [1053]),
#  ('httpstco0ryra559n0', 1, [115]),
#  ('pictur', 2, [559, 866]),
#  ('positionné', 1, [26]),
#  ('wwim15igerslausann', 2, [475, 476]),
#  ('potenti', 6, [69, 112, 158, 547, 677, 734]),
#  ('nwo', 1, [281]),
#  ('letslivetogetherepfl', 1, [1049]),
#  ('seedstarssummit', 1, [951]),
#  ('womensmarch', 2, [281, 582]),
#  ('flyabil', 1, [1036]),
#  ('deliveri', 1, [1061]),
#  ('xxe', 1, [123]),
#  ('dachat', 1, [325]),
#  ('fab', 1, [916]),
#  ('whose', 1, [979]),
#  ('balanc', 1, [581]),
#  ('therapeut', 1, [972]),
#  ('natureenergyjnl', 1, [834]),
#  ('neinzunobillag', 1, [144]),
#  ('désolé', 1, [199]),
#  ('organoid', 1, [607]),
#  ('powder', 1, [289]),
#  ('httpstco2eruzdhgxv', 1, [610]),
#  ('gettu', 1, [748]),
#  ('effect', 1, [217]),
#  ('soiréesbibliothèqu', 1, [96]),
#  ('wef17', 2, [396, 776]),
#  ('coeur', 1, [207]),
#  ('hackday', 1, [158]),
#  ('iucn', 1, [41]),
#  ('stromtanken', 1, [1011]),
#  ('reconnu', 1, [665]),
#  ('avril4', 1, [202]),
#  ('massiv', 1, [515]),
#  ('mission', 5, [138, 493, 554, 665, 798]),
#  ('inherit', 1, [422]),
#  ('time',
#   20,
#   [2,
#    12,
#    44,
#    68,
#    125,
#    164,
#    323,
#    326,
#    361,
#    397,
#    448,
#    497,
#    586,
#    719,
#    720,
#    830,
#    858,
#    888,
#    958,
#    1056]),
#  ('headgenev', 1, [705]),
#  ('mattia', 1, [154]),
#  ('your',
#   19,
#   [75,
#    98,
#    141,
#    307,
#    348,
#    394,
#    397,
#    448,
#    539,
#    575,
#    593,
#    642,
#    776,
#    907,
#    930,
#    937,
#    941,
#    1006,
#    1033]),
#  ('httpstcodenokqywrc', 1, [404]),
#  ('httpstcopiz1hi72jt', 1, [623]),
#  ('httpstcozzywdw6xbn', 1, [755]),
#  ('raconté', 1, [1022]),
#  ('dirti', 1, [941]),
#  ('san', 4, [70, 351, 927, 963]),
#  ('httpstcobtfmcsw0xp', 1, [970]),
#  ('offer', 9, [60, 73, 138, 184, 246, 332, 606, 839, 914]),
#  ('httpstcomass98crri', 2, [328, 527]),
#  ('httpstcourxfsarxc4', 1, [500]),
#  ('vacuumpow', 1, [17]),
#  ('stellar', 1, [269]),
#  ('httpstco1oxxxs6mg', 1, [1064]),
#  ('realiti', 5, [376, 444, 718, 907, 1014]),
#  ('strongli', 1, [987]),
#  ('vont', 1, [1026]),
#  ('httpstcomsnlgmpaol', 1, [246]),
#  ('httpstcouwfykmcz5p', 1, [297]),
#  ('centr', 5, [16, 182, 182, 723, 947]),
#  ('😆', 1, [716]),
#  ('bellon', 1, [419]),
#  ('mindblow', 1, [1014]),
#  ('youtubechanel', 1, [637]),
#  ('parrot', 1, [318]),
#  ('tumuenchen', 4, [71, 522, 669, 1006]),
#  ('auwerxlab', 1, [532]),
#  ('analyz', 1, [690]),
#  ('httpstcozjy1detl', 1, [993]),
#  ('photograph', 4, [44, 328, 527, 908]),
#  ('quil', 2, [287, 1024]),
#  ('cryo', 1, [526]),
#  ('obligatoir', 1, [277]),
#  ('independant', 1, [356]),
#  ('digitalday', 3, [382, 565, 671]),
#  ('respond', 1, [507]),
#  ('bradsmi', 2, [10, 830]),
#  ('post', 1, [286]),
#  ('panneaux', 1, [1023]),
#  ('tetsurokitahara', 1, [418]),
#  ('cérébrale', 1, [277]),
#  ('short', 2, [301, 518]),
#  ('httpstco4r7b6cemhk', 1, [849]),
#  ('httpstcoqfzdfohgpp', 1, [129]),
#  ('justinegdc', 1, [808]),
#  ('httpstcoockxeddtcn', 1, [935]),
#  ('introduc', 1, [407]),
#  ('high', 6, [428, 446, 611, 637, 639, 1055]),
#  ('amélior', 1, [149]),
#  ('nottheashleydunnor', 1, [32]),
#  ('angewchem', 1, [550]),
#  ('acquir', 1, [318]),
#  ('15', 3, [759, 967, 1015]),
#  ('detail', 2, [125, 888]),
#  ('rail', 1, [567]),
#  ('fifpro', 1, [291]),
#  ('42born2cod', 1, [561]),
#  ('also', 8, [30, 108, 108, 108, 150, 192, 323, 530]),
#  ('fairi', 1, [491]),
#  ('meinen', 1, [954]),
#  ('httpstcok34o7qqbnp', 1, [690]),
#  ('post2020🇪🇺rampi', 1, [126]),
#  ('comput', 6, [4, 30, 89, 333, 795, 838]),
#  ('upscal', 1, [36]),
#  ('cohabitonsepfl', 1, [1049]),
#  ('httpstcoyeqyacal3c', 1, [783]),
#  ('httpstcorm46e0v8gi', 1, [628]),
#  ('techcrunch', 3, [247, 615, 660]),
#  ('five', 2, [858, 858]),
#  ('hous', 6, [33, 294, 380, 468, 596, 596]),
#  ('ee559', 1, [859]),
#  ('capabl', 1, [610]),
#  ('einen', 1, [188]),
#  ('1200cet', 1, [992]),
#  ('httpstco4hmazta9qa', 1, [49]),
#  ('79', 2, [98, 578]),
#  ('michigan', 2, [294, 468]),
#  ('nobel', 2, [674, 720]),
#  ('may', 4, [263, 728, 732, 972]),
#  ('onlineschul', 1, [188]),
#  ('hasard', 1, [651]),
#  ('bubbl', 1, [75]),
#  ('variou', 1, [65]),
#  ('front', 2, [247, 615]),
#  ('humanité', 1, [958]),
#  ('triaud', 1, [1053]),
#  ('100', 4, [325, 429, 560, 767]),
#  ('cafe', 1, [1032]),
#  ('httpstcokm1p7dnpr4', 1, [919]),
#  ('fpbock', 1, [86]),
#  ('silk', 1, [172]),
#  ('privat', 2, [499, 957]),
#  ('drop', 2, [98, 141]),
#  ('partecipa', 1, [851]),
#  ('environment', 2, [101, 617]),
#  ('httpstcowt09cxhcaa', 1, [1050]),
#  ('anticanc', 1, [211]),
#  ('httpstcozi0urmutl5', 1, [279]),
#  ('ident', 1, [957]),
#  ('free', 13, [5, 15, 41, 166, 189, 232, 260, 348, 430, 493, 504, 946, 986]),
#  ('septemb', 3, [679, 885, 887]),
#  ('lappel', 1, [526]),
#  ('geneva', 4, [27, 525, 541, 903]),
#  ('httpstcofow8wqhbka', 1, [431]),
#  ('httpstconpcumuigef', 1, [342]),
#  ('messag', 1, [68]),
#  ('treatment', 2, [166, 547]),
#  ('summerschool', 1, [196]),
#  ('har', 1, [666]),
#  ('deeplearn', 5, [34, 165, 165, 521, 859]),
#  ('httpstcopdildcmmdc', 1, [752]),
#  ('httpstcoy2s3hz1817', 1, [796]),
#  ('jenmccutcheon', 1, [108]),
#  ('httpstcoevqyqd7ffl', 1, [30]),
#  ('httpstco4akq4dxkgd', 1, [430]),
#  ('verifi', 1, [581]),
#  ('addit', 3, [327, 883, 884]),
#  ('pierresern', 1, [687]),
#  ('coréenn', 1, [706]),
#  ('continuum', 1, [55]),
#  ('häuschen', 1, [451]),
#  ('httpstcomjlq4d3rwm', 1, [773]),
#  ('créon', 1, [610]),
#  ('oxid', 1, [334]),
#  ('httpstco3vujybmevd', 1, [341]),
#  ('coordin', 1, [851]),
#  ('bms2018', 1, [28]),
#  ('eat', 1, [813]),
#  ('sensima', 1, [53]),
#  ('l',
#   35,
#   [70,
#    123,
#    197,
#    197,
#    277,
#    282,
#    294,
#    363,
#    383,
#    388,
#    403,
#    463,
#    468,
#    495,
#    627,
#    644,
#    651,
#    665,
#    710,
#    800,
#    821,
#    843,
#    857,
#    862,
#    862,
#    889,
#    894,
#    901,
#    947,
#    958,
#    1023,
#    1025,
#    1026,
#    1026,
#    1071]),
#  ('previous', 1, [45]),
#  ('aebisch', 3, [702, 821, 1071]),
#  ('httpstconf1gerzfun', 1, [46]),
#  ('dhum', 3, [218, 460, 496]),
#  ('scienc',
#   34,
#   [4,
#    30,
#    49,
#    109,
#    131,
#    183,
#    201,
#    210,
#    250,
#    300,
#    301,
#    358,
#    393,
#    420,
#    420,
#    426,
#    443,
#    524,
#    544,
#    593,
#    600,
#    616,
#    688,
#    710,
#    713,
#    730,
#    743,
#    764,
#    778,
#    810,
#    904,
#    969,
#    1054,
#    1056]),
#  ('gordon', 1, [88]),
#  ('guy', 3, [238, 482, 621]),
#  ('miniprojektor', 1, [241]),
#  ('hecpari', 1, [482]),
#  ('gianpaolorando', 1, [416]),
#  ('venturelabch', 6, [120, 200, 227, 241, 447, 516]),
#  ('httpstcof47bx1wyki', 1, [514]),
#  ('held', 1, [126]),
#  ('brighten', 1, [870]),
#  ('forumwslsuisseromand', 1, [653]),
#  ('biociment', 1, [283]),
#  ('httpstcon2fe3bxfzh', 1, [13]),
#  ('etiquett', 1, [292]),
#  ('streamlin', 1, [98]),
#  ('snhtweet', 1, [630]),
#  ('origami', 3, [407, 407, 719]),
#  ('gafa', 1, [921]),
#  ('osspari', 1, [176]),
#  ('bell', 2, [172, 829]),
#  ('electricvehicl', 1, [642]),
#  ('retir', 1, [988]),
#  ('him', 1, [142]),
#  ('httpstco0iqt3k8fkq', 1, [32]),
#  ('httpstco2wg3bbhbnq', 1, [426]),
#  ('elaudierlaudi', 1, [530]),
#  ('historiqu', 1, [1042]),
#  ('femm', 1, [488]),
#  ('give', 6, [32, 213, 312, 418, 518, 765]),
#  ('psychologist', 1, [507]),
#  ('fantast', 6, [19, 78, 114, 648, 970, 987]),
#  ('pc', 1, [274]),
#  ('thingofbeauti', 1, [749]),
#  ('disast', 1, [519]),
#  ('faculté', 2, [633, 925]),
#  ('trace', 4, [24, 67, 153, 932]),
#  ('woman', 1, [956]),
#  ('ariel', 1, [56]),
#  ('tort', 1, [439]),
#  ('linnov', 2, [902, 1054]),
#  ('covestrogroup', 2, [76, 933]),
#  ('void', 1, [410]),
#  ('humanbrainproj', 1, [709]),
#  ('whole', 2, [95, 691]),
#  ('porto', 1, [306]),
#  ('topic', 8, [10, 134, 350, 466, 502, 526, 628, 643]),
#  ('httpstcojoyiuoroh', 1, [94]),
#  ('▶️want', 1, [102]),
#  ('httpstcoqczodmndjj', 1, [570]),
#  ('imdepfl', 1, [57]),
#  ('imd', 2, [57, 1026]),
#  ('mair', 1, [463]),
#  ('httpstcoynay98tg4b', 1, [622]),
#  ('nestor', 1, [927]),
#  ('enhanc', 4, [349, 668, 708, 864]),
#  ('httpstcoit0sbqlkqc', 1, [228]),
#  ('curvilinear', 1, [680]),
#  ('httpstcoqr5bho3ejh', 1, [794]),
#  ('harvardm', 3, [359, 481, 556]),
#  ('httpstcoqgwo4mcpjt', 1, [754]),
#  ('manifest', 1, [822]),
#  ('traceepfl', 1, [69]),
#  ('onboard', 1, [666]),
#  ('rank', 6, [4, 121, 220, 675, 912, 1041]),
#  ('vitrag', 1, [1070]),
#  ('httpstcoykiuxexnrt', 1, [649]),
#  ('travail', 4, [11, 63, 93, 996]),
#  ('montagn', 1, [388]),
#  ('httpstcod5gqfbidsf', 1, [632]),
#  ('oscienc', 9, [24, 67, 111, 153, 328, 355, 527, 811, 932]),
#  ('réaménag', 1, [1063]),
#  ('touchabl', 1, [435]),
#  ('dream', 1, [667]),
#  ('exposur', 2, [420, 730]),
#  ('5d', 2, [849, 1073]),
#  ('bald', 1, [1015]),
#  ('hunt', 2, [173, 854]),
#  ('magistretti', 1, [741]),
#  ('jp', 1, [724]),
#  ('httpstco7lr3x8nkqn', 1, [1029]),
#  ('week',
#   16,
#   [77,
#    78,
#    124,
#    125,
#    125,
#    147,
#    399,
#    464,
#    466,
#    481,
#    516,
#    563,
#    623,
#    778,
#    973,
#    1006]),
#  ('produktivität', 1, [425]),
#  ('éblouit', 1, [300]),
#  ('committe', 2, [306, 336]),
#  ('httpstcobeq7t6h43v', 1, [667]),
#  ('httpstcooe6jhuulm9', 1, [169]),
#  ('httpstconctmpw0ba3', 1, [37]),
#  ('hackdisrupt', 1, [218]),
#  ('gopro', 1, [1036]),
#  ('informatik', 1, [309]),
#  ('fate', 1, [607]),
#  ('hot', 1, [1014]),
#  ('1', 11, [30, 61, 100, 121, 266, 422, 471, 572, 880, 936, 1031]),
#  ('satoshi', 1, [88]),
#  ('httpstco5qiiwlrwqj', 1, [129]),
#  ('endosymbiont', 1, [809]),
#  ('erstmal', 1, [638]),
#  ('prosecitor', 1, [163]),
#  ('httpstcoufbrxo4nqf', 1, [572]),
#  ('tough', 1, [650]),
#  ('sec', 1, [492]),
#  ('schweizer', 1, [25]),
#  ('rethink', 1, [762]),
#  ('joe', 1, [620]),
#  ('tesla', 1, [209]),
#  ('haptic', 2, [102, 102]),
#  ('httpstcosnvl20jkaf', 1, [812]),
#  ('challeng', 6, [71, 158, 267, 492, 657, 724]),
#  ('headlin', 2, [630, 808]),
#  ('httpstconyebnjz9iq', 1, [726]),
#  ('grante', 1, [717]),
#  ('httpstcov3tojtyjqd', 1, [3]),
#  ('httpstcooyguvk0le4', 1, [64]),
#  ('regist', 8, [23, 135, 180, 200, 464, 614, 704, 756]),
#  ('snowfal', 2, [150, 185]),
#  ('besson', 1, [855]),
#  ('leben', 1, [188]),
#  ('httpstco9j5gplmcoi', 1, [481]),
#  ('violainese', 3, [80, 100, 685]),
#  ('prédécesseur', 1, [665]),
#  ('convers', 3, [681, 863, 911]),
#  ('httpstcoeozeypyi68', 1, [192]),
#  ('httpstcomowbfucy7i', 1, [282]),
#  ('httpstcovtwtstrorc', 1, [761]),
#  ('revolut', 2, [863, 869]),
#  ('when', 6, [134, 206, 211, 540, 581, 979]),
#  ('2015', 1, [241]),
#  ('ict4dev', 1, [46]),
#  ('httpstcojgfkumdvyi', 1, [164]),
#  ('’',
#   81,
#   [13,
#    32,
#    44,
#    58,
#    58,
#    60,
#    62,
#    107,
#    123,
#    144,
#    152,
#    197,
#    197,
#    243,
#    243,
#    243,
#    248,
#    278,
#    282,
#    282,
#    282,
#    337,
#    363,
#    373,
#    388,
#    403,
#    411,
#    414,
#    414,
#    453,
#    473,
#    495,
#    517,
#    532,
#    543,
#    584,
#    589,
#    604,
#    610,
#    610,
#    627,
#    627,
#    627,
#    627,
#    630,
#    644,
#    665,
#    684,
#    691,
#    691,
#    692,
#    710,
#    723,
#    731,
#    755,
#    770,
#    770,
#    800,
#    817,
#    821,
#    843,
#    843,
#    849,
#    849,
#    851,
#    853,
#    861,
#    862,
#    862,
#    901,
#    935,
#    958,
#    968,
#    975,
#    1023,
#    1025,
#    1026,
#    1026,
#    1040,
#    1067,
#    1071]),
#  ('subwavelength', 1, [36]),
#  ('motivé', 2, [168, 197]),
#  ('bonjour', 1, [467]),
#  ('sothebi', 1, [849]),
#  ('mobilepay', 1, [700]),
#  ('incubateur', 1, [297]),
#  ('gain', 2, [346, 790]),
#  ('baumann', 1, [613]),
#  ('httpstcoyrkoycbsl', 1, [1022]),
#  ('httpstcouczjzmnfyf', 1, [255]),
#  ('newdawn', 1, [608]),
#  ('httpstco50enztwuhi', 1, [562]),
#  ('electron', 3, [504, 865, 903]),
#  ('trunk', 1, [290]),
#  ('httpstcovcqxjwcrfr', 1, [944]),
#  ('1989', 1, [720]),
#  ('acsnano', 1, [916]),
#  ('polair', 1, [636]),
#  ('home', 2, [83, 155]),
#  ('through', 2, [108, 878]),
#  ('httpstcor7ml9nj9lo', 1, [946]),
#  ('httpstcomfrjlnuopt', 1, [662]),
#  ('swissnexsf', 5, [215, 241, 247, 313, 963]),
#  ('call', 4, [222, 224, 393, 688]),
#  ('structur', 1, [959]),
#  ('degrad', 1, [986]),
#  ('joetheshark', 1, [620]),
#  ('httpstcoqgyot0yvzn', 1, [545]),
#  ('order', 1, [87]),
#  ('njit', 1, [77]),
#  ('dashboard', 1, [776]),
#  ('servic', 1, [644]),
#  ('exempl', 1, [183]),
#  ('glückwunsch', 1, [954]),
#  ('swissfilm', 1, [313]),
#  ('premier', 4, [390, 464, 570, 939]),
#  ('chui', 1, [287]),
#  ('said', 1, [938]),
#  ('pilot', 1, [429]),
#  ('data',
#   22,
#   [27,
#    34,
#    80,
#    117,
#    125,
#    250,
#    315,
#    415,
#    426,
#    442,
#    443,
#    466,
#    466,
#    558,
#    600,
#    625,
#    666,
#    673,
#    685,
#    741,
#    930,
#    957]),
#  ('point', 7, [108, 175, 251, 272, 292, 312, 1067]),
#  ('what',
#   22,
#   [139,
#    204,
#    278,
#    278,
#    359,
#    397,
#    409,
#    448,
#    474,
#    481,
#    516,
#    521,
#    580,
#    613,
#    671,
#    699,
#    717,
#    799,
#    938,
#    956,
#    995,
#    1060]),
#  ('daylight', 1, [376]),
#  ('httpstcoxgb8ynuklt', 1, [585]),
#  ('socialventur', 1, [589]),
#  ('mpicbg', 2, [638, 745]),
#  ('dashdawai', 1, [952]),
#  ('httpstcooxyrjroudp', 1, [962]),
#  ('evot', 1, [903]),
#  ('httpstcoxnxlvbbkyr', 1, [438]),
#  ('httpstcot3v91hjq8m', 1, [270]),
#  ('scolair', 1, [783]),
#  ('scientif', 2, [13, 103]),
#  ('olivi', 1, [419]),
#  ('metabolismcontext', 1, [850]),
#  ('findet', 1, [167]),
#  ('httpstco4uidxckvaq', 1, [172]),
#  ('avril', 2, [633, 894]),
#  ('peac', 1, [263]),
#  ('befcorreiahantschelmblokesch', 1, [593]),
#  ('energystorag', 2, [117, 642]),
#  ('porcelain', 1, [770]),
#  ('httpstcowejk5iwilc', 1, [623]),
#  ('körper', 1, [638]),
#  ('httpstcomjqcrfiqkb', 1, [30]),
#  ('httpstcoybrips5tw8', 1, [647]),
#  ('est',
#   15,
#   [61,
#    252,
#    382,
#    604,
#    627,
#    627,
#    627,
#    659,
#    665,
#    729,
#    766,
#    929,
#    996,
#    1016,
#    1031]),
#  ('httpstcovhf2qdgetx', 1, [235]),
#  ('mélodi', 1, [942]),
#  ('sauver', 1, [123]),
#  ('erc', 1, [717]),
#  ('thuner', 1, [338]),
#  ('scicommfilmhack', 1, [420]),
#  ('cerveau', 1, [362]),
#  ('hack', 3, [587, 587, 587]),
#  ('httpstcowirwfhou4i', 1, [258]),
#  ('kaust', 2, [622, 741]),
#  ('fsrmch', 1, [200]),
#  ('could',
#   14,
#   [131, 314, 354, 396, 532, 558, 577, 695, 712, 813, 813, 966, 997, 1034]),
#  ('here',
#   15,
#   [44, 103, 185, 262, 278, 348, 353, 466, 559, 576, 635, 678, 688, 743, 937]),
#  ('inform', 9, [65, 109, 134, 144, 236, 342, 512, 573, 644]),
#  ('httpstcoryqo5z3jhk', 1, [132]),
#  ('zu', 8, [319, 319, 619, 638, 638, 701, 890, 890]),
#  ('gafam', 1, [924]),
#  ('httpstcoluq7bwf0mh', 1, [386]),
#  ('cnrscentreest', 1, [304]),
#  ('aristotl', 1, [221]),
#  ('création', 2, [723, 996]),
#  ('epflcdm', 1, [817]),
#  ('by',
#   79,
#   [4,
#    15,
#    22,
#    27,
#    35,
#    46,
#    53,
#    68,
#    68,
#    74,
#    75,
#    86,
#    98,
#    99,
#    104,
#    114,
#    126,
#    132,
#    145,
#    163,
#    164,
#    184,
#    193,
#    196,
#    222,
#    237,
#    239,
#    242,
#    248,
#    250,
#    260,
#    262,
#    275,
#    284,
#    292,
#    294,
#    303,
#    303,
#    314,
#    318,
#    323,
#    372,
#    376,
#    390,
#    416,
#    428,
#    468,
#    469,
#    480,
#    513,
#    521,
#    534,
#    573,
#    585,
#    586,
#    594,
#    596,
#    597,
#    607,
#    624,
#    666,
#    669,
#    678,
#    684,
#    720,
#    745,
#    748,
#    786,
#    790,
#    827,
#    833,
#    928,
#    953,
#    957,
#    959,
#    959,
#    1003,
#    1032,
#    1061]),
#  ('especi', 1, [716]),
#  ('buec', 1, [916]),
#  ('httpstcoulurhrsqwi', 1, [353]),
#  ('saturday', 1, [525]),
#  ('httpstcoe0libndjkc', 1, [671]),
#  ('vallebenasqu', 1, [431]),
#  ('grant', 3, [53, 697, 697]),
#  ('4person', 1, [1014]),
#  ('httpstcoyaklj6rwyz', 1, [887]),
#  ('evolut', 1, [969]),
#  ('natxopago', 1, [335]),
#  ('msc', 1, [323]),
#  ('httpstcoixkk2ofku', 1, [388]),
#  ('httpstcoh7tpm4gwmk', 1, [353]),
#  ('periperson', 1, [290]),
#  ('vitamin', 1, [149]),
#  ('rémi', 1, [463]),
#  ('httpstcoihyjn6az2i', 1, [242]),
#  ('chronic', 1, [907]),
#  ('asemday', 1, [270]),
#  ('timeshigh', 4, [121, 139, 319, 934]),
#  ('rememb', 1, [409]),
#  ('lehner', 1, [62]),
#  ('2017',
#   24,
#   [48,
#    48,
#    63,
#    121,
#    154,
#    178,
#    265,
#    420,
#    422,
#    431,
#    538,
#    560,
#    609,
#    705,
#    730,
#    887,
#    929,
#    931,
#    934,
#    975,
#    1015,
#    1062,
#    1064,
#    1066]),
#  ('chrlovi', 1, [116]),
#  ('neue', 2, [167, 638]),
#  ('catégori', 1, [383]),
#  ('tool', 7, [101, 229, 314, 616, 625, 713, 904]),
#  ('thomasoppermann', 3, [1057, 1058, 1059]),
#  ('seen', 2, [691, 751]),
#  ('hopitauxunig', 3, [116, 357, 437]),
#  ('humanitarian', 3, [830, 856, 975]),
#  ('newscientist', 1, [1029]),
#  ('httpstcoqb0t28tdtq', 1, [1019]),
#  ('leçon', 2, [172, 843]),
#  ('christma', 3, [600, 719, 820]),
#  ('14h', 2, [345, 604]),
#  ('plaît', 1, [467]),
#  ('coorpacademi', 1, [273]),
#  ('promis', 3, [406, 486, 693]),
#  ('ethrat', 3, [10, 64, 785]),
#  ('electroluminesc', 1, [303]),
#  ('pervert', 1, [979]),
#  ('nberpub', 4, [294, 294, 468, 468]),
#  ('interview', 6, [69, 181, 702, 741, 795, 905]),
#  ('medit', 1, [221]),
#  ('karen', 1, [748]),
#  ('scil', 1, [619]),
#  ('link', 1, [732]),
#  ('overview', 1, [984]),
#  ('from',
#   77,
#   [22,
#    30,
#    32,
#    59,
#    59,
#    83,
#    89,
#    100,
#    108,
#    164,
#    223,
#    227,
#    247,
#    260,
#    271,
#    276,
#    303,
#    318,
#    335,
#    359,
#    365,
#    365,
#    409,
#    413,
#    414,
#    416,
#    427,
#    427,
#    444,
#    464,
#    469,
#    481,
#    486,
#    499,
#    507,
#    515,
#    532,
#    535,
#    535,
#    545,
#    562,
#    563,
#    575,
#    587,
#    591,
#    593,
#    607,
#    608,
#    614,
#    615,
#    622,
#    630,
#    648,
#    655,
#    663,
#    694,
#    694,
#    712,
#    731,
#    734,
#    734,
#    735,
#    738,
#    765,
#    776,
#    831,
#    847,
#    849,
#    849,
#    855,
#    905,
#    930,
#    966,
#    992,
#    1013,
#    1033,
#    1064]),
#  ('httpstcorlzk8c5ata', 1, [546]),
#  ('kurs', 1, [167]),
#  ('httpstcorvquoky5tq', 1, [965]),
#  ('we',
#   36,
#   [60,
#    65,
#    65,
#    78,
#    98,
#    108,
#    134,
#    134,
#    191,
#    203,
#    221,
#    223,
#    247,
#    264,
#    281,
#    307,
#    333,
#    346,
#    353,
#    414,
#    445,
#    572,
#    580,
#    601,
#    671,
#    703,
#    760,
#    802,
#    863,
#    886,
#    909,
#    935,
#    963,
#    1013,
#    1046,
#    1065]),
#  ('dommag', 1, [149]),
#  ('insid', 5, [24, 67, 153, 245, 932]),
#  ('vidéo', 1, [893]),
#  ('nobillag', 1, [144]),
#  ('station', 2, [671, 1063]),
#  ('puissant', 1, [921]),
#  ('hubbl', 3, [111, 355, 811]),
#  ('réseau', 1, [1063]),
#  ('httpstcofc9t0gbuhx', 1, [689]),
#  ('httpstcorgsyaedoci', 1, [829]),
#  ('carri', 2, [430, 777]),
#  ('lc3technolog', 1, [748]),
#  ('httpstcobuda7w2icm', 1, [629]),
#  ('httpstcoqzv4saerzq', 1, [178]),
#  ('carv', 2, [256, 389]),
#  ('x2ai', 2, [50, 722]),
#  ('artifici', 7, [69, 237, 546, 547, 750, 797, 1055]),
#  ('httpstcoxxtf4agbqb', 1, [902]),
#  ('félicit', 1, [954]),
#  ('identifi', 4, [35, 170, 734, 880]),
#  ('httpstcojs4tewsguh', 1, [147]),
#  ('httpstcogq9outmsd4', 1, [399]),
#  ('investig', 4, [303, 446, 661, 979]),
#  ('slice', 1, [497]),
#  ('httpstcozfq3kf9r6r', 1, [617]),
#  ('grâce', 1, [882]),
#  ('glass', 2, [225, 234]),
#  ('work',
#   32,
#   [14,
#    76,
#    86,
#    88,
#    151,
#    262,
#    296,
#    301,
#    323,
#    352,
#    414,
#    428,
#    500,
#    507,
#    526,
#    591,
#    655,
#    667,
#    667,
#    717,
#    761,
#    791,
#    855,
#    856,
#    864,
#    897,
#    931,
#    935,
#    938,
#    960,
#    1046,
#    1065]),
#  ('nonalcohol', 1, [298]),
#  ('fleshandblood', 2, [216, 634]),
#  ('healthcar', 1, [897]),
#  ('robot',
#   50,
#   [9,
#    14,
#    17,
#    31,
#    86,
#    102,
#    102,
#    104,
#    169,
#    169,
#    208,
#    246,
#    249,
#    254,
#    292,
#    353,
#    379,
#    379,
#    407,
#    407,
#    407,
#    414,
#    414,
#    414,
#    414,
#    425,
#    440,
#    450,
#    585,
#    585,
#    599,
#    647,
#    651,
#    660,
#    703,
#    719,
#    774,
#    835,
#    835,
#    871,
#    897,
#    905,
#    924,
#    926,
#    942,
#    972,
#    1008,
#    1029,
#    1033,
#    1038]),
#  ('propos', 4, [200, 341, 346, 391]),
#  ('httpstcoivlpjaimhi', 2, [256, 389]),
#  ('board', 3, [60, 359, 950]),
#  ('nm2', 1, [135]),
#  ('httpstcokf6e0am2kb', 1, [51]),
#  ('geomechaepfl', 3, [512, 601, 710]),
#  ('httpstcouhcezifc7t', 1, [347]),
#  ('doesnt', 1, [1002]),
#  ('sdg', 1, [1007]),
#  ('incorpor', 1, [292]),
#  ('illustré', 1, [739]),
#  ('pie', 1, [383]),
#  ('créé', 1, [1047]),
#  ('label', 1, [557]),
#  ('pribabl', 1, [535]),
#  ('shouldnt', 1, [556]),
#  ('worldli', 1, [675]),
#  ('mental', 1, [627]),
#  ('eurosys2018', 3, [274, 306, 306]),
#  ('moniqu', 1, [1021]),
#  ('nm2conf', 3, [135, 179, 223]),
#  ('sxsw', 3, [50, 215, 722]),
#  ('gehendragurung', 1, [350]),
#  ('pendant', 1, [268]),
#  ('ediblerobot', 1, [732]),
#  ('pourrait', 2, [682, 789]),
#  ('forum', 1, [13]),
#  ('symbionthost', 1, [55]),
#  ('lot', 3, [903, 909, 933]),
#  ('ladysmith', 1, [272]),
#  ('rina1861', 1, [639]),
#  ('dotsecurityio', 1, [213]),
#  ('httpstcomyyi0qn04g', 1, [745]),
#  ('acmepfl', 1, [914]),
#  ('methyl', 1, [66]),
#  ('décret', 1, [1054]),
#  ('httpstco5tmqyjekih', 1, [110]),
#  ('ancien', 1, [1017]),
#  ('httpstcodpemd35x1r', 1, [260]),
#  ('slim', 1, [170]),
#  ('savmap', 1, [235]),
#  ('adjust', 1, [84]),
#  ('transient', 1, [66]),
#  ('ngi4eu', 1, [549]),
#  ('httpstcosikakpfu0o', 1, [684]),
#  ('dotastro', 1, [869]),
#  ('stewart', 1, [579]),
#  ('gräeff', 1, [622]),
#  ('salgado', 1, [231]),
#  ('société', 1, [565]),
#  ('stakehold', 1, [748]),
#  ('dexpo', 1, [194]),
#  ('realen', 1, [737]),
#  ('list', 3, [246, 295, 899]),
#  ('smartgrid', 1, [510]),
#  ('httpstcoiwtbu2mfyr', 1, [554]),
#  ('biofuel', 2, [965, 965]),
#  ('httpstcoomq1u70jz4', 1, [851]),
#  ('httpstcose4qjvm6z2', 1, [543]),
#  ('solvingproblem', 1, [714]),
#  ('rather', 1, [580]),
#  ('alp', 2, [150, 150]),
#  ('epflfood', 1, [253]),
#  ('demain', 4, [39, 243, 265, 1037]),
#  ('knecht', 2, [137, 506]),
#  ('entdeckt', 1, [451]),
#  ('httpstcobymmkjagz1', 1, [1042]),
#  ('httpstcoc8ssuixmmg', 1, [215]),
#  ('httpstcovzvmpcj3hv', 1, [102]),
#  ('technologisteu', 3, [217, 648, 669]),
#  ('disgrac', 1, [281]),
#  ('httpstcoe2ogm9ze7v', 1, [992]),
#  ('10pm', 1, [655]),
#  ('don', 1, [278]),
#  ('icymi', 1, [595]),
#  ('lexosquelett', 1, [172]),
#  ('due', 2, [150, 185]),
#  ('ecargobik', 1, [430]),
#  ('extrêmement', 1, [742]),
#  ('tournament', 1, [535]),
#  ('httpstcoggucszbsxr', 1, [523]),
#  ('demonstr', 2, [104, 909]),
#  ('mathemat', 1, [717]),
#  ('bottom', 1, [589]),
#  ('donat', 1, [546]),
#  ('beltandroad', 1, [639]),
#  ('httpstcojtheq7sb9d', 1, [491]),
#  ('distanc', 2, [627, 838]),
#  ('httpstcogykdblzsr5', 1, [660]),
#  ('organisé', 1, [1018]),
#  ('nips2016', 1, [97]),
#  ('httpstcolb223yt804', 1, [92]),
#  ('rural', 1, [46]),
#  ('engag', 3, [66, 66, 724]),
#  ('httpstcodoe5shp9xr', 1, [477]),
#  ('quun', 1, [325]),
#  ('character', 1, [159]),
#  ('damasio', 1, [472]),
#  ('temperatur', 1, [769]),
#  ('technionl', 1, [522]),
#  ('today',
#   22,
#   [143,
#    154,
#    191,
#    258,
#    270,
#    320,
#    411,
#    412,
#    480,
#    518,
#    528,
#    630,
#    700,
#    707,
#    712,
#    764,
#    878,
#    903,
#    905,
#    966,
#    992,
#    1032]),
#  ('httpstcoicgwb6puwo', 1, [597]),
#  ('séminair', 1, [874]),
#  ('►', 1, [647]),
#  ('backtoschool', 1, [679]),
#  ('mscrobot', 1, [246]),
#  ('multijunct', 2, [398, 681]),
#  ('nahrungssicherheit', 1, [721]),
#  ('amin', 2, [142, 195]),
#  ('httpstcor5vbp61wqi', 1, [739]),
#  ('guitar', 1, [787]),
#  ('httpstcosi9sz9cxpv', 1, [257]),
#  ('⚠️caution⚠️', 1, [150]),
#  ('qgelbio', 1, [499]),
#  ('raven', 1, [189]),
#  ('lowcost', 2, [217, 918]),
#  ('cowork', 1, [253]),
#  ('httpstcon6d0dgje0v', 1, [790]),
#  ('edg', 1, [410]),
#  ('ac', 2, [264, 879]),
#  ('httpstcoyafnd9cior', 1, [674]),
#  ('green', 6, [152, 171, 473, 517, 853, 968]),
#  ('induc', 1, [469]),
#  ('httpstcochibnceiwj', 1, [125]),
#  ('diplom', 1, [188]),
#  ('cocktail', 1, [591]),
#  ('jure', 1, [557]),
#  ('pv', 2, [184, 913]),
#  ('umformungsprozessen', 1, [638]),
#  ('bourgd', 1, [729]),
#  ('code', 8, [233, 347, 525, 528, 636, 707, 742, 752]),
#  ('httpstcosopg4xegjf', 1, [711]),
#  ('sex', 1, [928]),
#  ('httpstcobid211ncnp', 1, [558]),
#  ('virtualswiss', 1, [624]),
#  ('uefa', 3, [128, 291, 992]),
#  ('place', 12, [0, 0, 137, 283, 429, 560, 764, 873, 886, 976, 977, 1048]),
#  ('mytechni', 1, [800]),
#  ('httpstco16zzhx0prn', 1, [843]),
#  ('mdeff', 1, [816]),
#  ('hsgstgallen', 1, [16]),
#  ('biophys', 2, [378, 795]),
#  ('be',
#   40,
#   [65,
#    78,
#    80,
#    102,
#    108,
#    213,
#    236,
#    263,
#    267,
#    314,
#    325,
#    374,
#    411,
#    447,
#    457,
#    479,
#    501,
#    513,
#    519,
#    547,
#    594,
#    613,
#    613,
#    655,
#    660,
#    666,
#    715,
#    715,
#    760,
#    791,
#    845,
#    846,
#    863,
#    903,
#    909,
#    915,
#    999,
#    1002,
#    1028,
#    1072]),
#  ('readi', 5, [189, 554, 772, 786, 859]),
#  ('sciencebiencomm', 1, [393]),
#  ('know', 4, [102, 215, 353, 778]),
#  ('sest', 1, [548]),
#  ('launch', 9, [57, 421, 453, 504, 506, 559, 586, 677, 703]),
#  ('session', 5, [223, 294, 393, 468, 991]),
#  ('peter', 1, [957]),
#  ('reatch', 1, [572]),
#  ('httpstcouui9tmgnxt', 1, [916]),
#  ('réalitéaugmenté', 1, [251]),
#  ('grave', 1, [922]),
#  ('attract', 1, [577]),
#  ('excel', 6, [264, 292, 308, 576, 657, 800]),
#  ('httpstco0bajjgzvtj', 1, [465]),
#  ('notr', 7, [63, 243, 362, 565, 710, 821, 927]),
#  ('onlin', 6, [89, 167, 248, 418, 515, 899]),
#  ('faster', 1, [379]),
#  ('httpstcoqnijn705t9', 1, [1065]),
#  ('🇨🇭', 2, [241, 382]),
#  ('astronom', 1, [869]),
#  ('mindmazesa', 2, [120, 433]),
#  ('kawaii', 1, [715]),
#  ('bbc', 3, [216, 634, 634]),
#  ('httpstcoum0imlludj', 1, [361]),
#  ('wwim15', 2, [475, 476]),
#  ('recommand', 1, [603]),
#  ('professor', 9, [69, 195, 504, 579, 612, 741, 741, 795, 950]),
#  ('nrel', 5, [398, 595, 681, 771, 834]),
#  ('smlotzd', 1, [732]),
#  ('chip', 2, [865, 916]),
#  ('🎧', 2, [168, 197]),
#  ('overlayjourn', 1, [799]),
#  ('ceremoni', 5, [137, 238, 255, 288, 767]),
#  ('donn', 1, [644]),
#  ('disconcert', 1, [951]),
#  ('abandonnerai', 1, [1021]),
#  ('mise', 1, [844]),
#  ('httpstcoxdbiszjw1u', 1, [992]),
#  ('lead', 7, [139, 237, 354, 558, 577, 712, 966]),
#  ('httpstco60smllndjx', 1, [330]),
#  ('httpstco9d256rj7ct', 1, [769]),
#  ('highway', 3, [787, 787, 787]),
#  ('cosmoorbu', 1, [472]),
#  ('sendai', 1, [519]),
#  ('forêt', 3, [543, 653, 784]),
#  ('ou', 3, [815, 874, 1051]),
#  ('thanksforthefollow', 2, [330, 819]),
#  ('predisposit', 1, [494]),
#  ('pollut', 3, [145, 926, 1008]),
#  ('sfsch', 1, [148]),
#  ('psncnewslightbox', 1, [428]),
#  ('httpstcoepymyqckzw', 1, [1048]),
#  ('dévoilé', 1, [362]),
#  ('els', 3, [59, 791, 840]),
#  ('solarimpuls', 1, [620]),
#  ('connai', 1, [199]),
#  ('assist', 3, [693, 852, 972]),
#  ('conclud', 1, [563]),
#  ('readtoreef', 1, [814]),
#  ('between', 4, [71, 103, 126, 743]),
#  ('transgend', 1, [281]),
#  ('httpstcoty35u7vfah', 1, [712]),
#  ('marchand', 1, [1068]),
#  ('team',
#   13,
#   [27, 178, 276, 364, 400, 481, 551, 561, 667, 746, 771, 986, 1014]),
#  ('8pm', 1, [671]),
#  ('foresti', 1, [653]),
#  ('gt', 6, [66, 210, 441, 492, 887, 1032]),
#  ('microprojector', 1, [624]),
#  ('😂', 2, [540, 1052]),
#  ('deco', 1, [1020]),
#  ('oh', 1, [620]),
#  ('comechatwithm', 1, [765]),
#  ('httpstcogos2e6k7ba', 1, [303]),
#  ('naturel', 1, [788]),
#  ('startupfit', 2, [286, 891]),
#  ('smartbuild', 1, [510]),
#  ('zotero', 5, [61, 439, 682, 840, 939]),
#  ('mobilitätswend', 1, [1011]),
#  ('cancertreat', 1, [529]),
#  ('httpstcot4benvtkul', 1, [630]),
#  ('jordimontserrat', 2, [120, 953]),
#  ('dass', 1, [241]),
#  ('httpstcorhuhh0jm97', 1, [885]),
#  ('httpstcotaqf8volq', 1, [365]),
#  ('von', 8, [48, 241, 425, 425, 737, 737, 890, 969]),
#  ('bon', 3, [168, 325, 682]),
#  ('bürgi', 1, [948]),
#  ('pavilion', 1, [770]),
#  ('eric', 1, [327]),
#  ('lart', 1, [327]),
#  ('seem', 1, [373]),
#  ('httpstcoyq7umjzvin', 1, [180]),
#  ('cohabit', 1, [491]),
#  ('store', 1, [217]),
#  ('exutcae', 1, [88]),
#  ('dtutweet', 2, [71, 1006]),
#  ('exhibitiondesign', 1, [841]),
#  ('microbi', 1, [555]),
#  ('develop',
#   21,
#   [31,
#    132,
#    159,
#    166,
#    169,
#    229,
#    419,
#    440,
#    551,
#    577,
#    577,
#    607,
#    624,
#    647,
#    677,
#    678,
#    684,
#    712,
#    732,
#    966,
#    980]),
#  ('httpstcooamiwkxmgm', 1, [644]),
#  ('decaathlon', 1, [705]),
#  ('♻🔆', 1, [757]),
#  ('assembl', 1, [378]),
#  ('docomomo', 1, [633]),
#  ('twiiceoffici', 2, [172, 649]),
#  ('s',
#   27,
#   [13,
#    44,
#    58,
#    58,
#    104,
#    114,
#    152,
#    248,
#    292,
#    337,
#    473,
#    517,
#    532,
#    589,
#    592,
#    630,
#    684,
#    755,
#    770,
#    770,
#    817,
#    849,
#    849,
#    853,
#    935,
#    968,
#    975]),
#  ('httpstcopeme43mdfn', 1, [140]),
#  ('alahi', 3, [69, 104, 292]),
#  ('caban', 1, [388]),
#  ('httpstcohxsovlrngb', 1, [107]),
#  ('engadget', 1, [647]),
#  ('hundr', 2, [899, 899]),
#  ('httpstcot528zfgtmn', 1, [23]),
#  ('built', 3, [442, 1014, 1055]),
#  ('twodimension', 2, [545, 663]),
#  ('seminar', 2, [336, 946]),
#  ('nvmt', 1, [77]),
#  ('httpstcopuml0rsj8d', 1, [782]),
#  ('scientistswhoselfi', 1, [288]),
#  ('bruit', 2, [571, 571]),
#  ('httpstcogk95auonyf', 1, [717]),
#  ...]
